# %% [markdown]
# # Simple RNN Architecture

# %%
import os
os.environ['KERAS_BACKEND'] = 'tensorflow'
import keras

# %%
model = keras.Sequential([
    keras.layers.Input(shape=(4,5)),
    keras.layers.SimpleRNN(units=3),
    keras.layers.Dense(units=1,activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_2 (SimpleRNN)        │ (None, 3)              │            27 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31 (124.00 B)
#  Trainable params: 31 (124.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
print(model.get_weights()[0].shape)
model.get_weights()
# Out:
# (5, 3)
# [array([[-0.3151846 , -0.7372608 ,  0.18989629],
#         [-0.15468955,  0.05814362, -0.4960566 ],
#         [ 0.07301277, -0.75505126, -0.165021  ],
#         [ 0.8306349 , -0.08524919,  0.3509503 ],
#         [-0.48969898,  0.8070491 , -0.8492719 ]], dtype=float32),
#  array([[ 0.6018851 , -0.6688148 ,  0.43637276],
#         [ 0.75065994,  0.6602745 , -0.023397  ],
#         [ 0.27247748, -0.34164986, -0.89946175]], dtype=float32),
#  array([0., 0., 0.], dtype=float32),
#  array([[ 1.1500574 ],
#         [ 0.1811043 ],
#         [-0.30372113]], dtype=float32),
#  array([0.], dtype=float32)]
