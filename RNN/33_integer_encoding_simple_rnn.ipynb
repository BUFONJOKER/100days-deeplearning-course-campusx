# %% [markdown]
# # Integer Encoding Simple RNN

# %%
import os
os.environ['KERAS_BACKEND'] = 'tensorflow'
import keras
import numpy as np

# %%
docs = ['go india',
		'india india',
		'hip hip hurray',
		'jeetega bhai jeetega india jeetega',
		'bharat mata ki jai',
		'kohli kohli',
		'sachin sachin',
		'dhoni dhoni',
		'modi ji ki jai',
		'inquilab zindabad']

# %%
tokenizer = keras.preprocessing.text.Tokenizer()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3563793859.py in <cell line: 0>()
# ----> 1 tokenizer = keras.preprocessing.text.Tokenizer()
#
# AttributeError: module 'keras.preprocessing' has no attribute 'text'
